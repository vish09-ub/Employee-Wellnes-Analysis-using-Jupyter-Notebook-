# %%
import pandas as pd

# Use the exact name of your file
df = pd.read_excel("ewd_clean.xlsx")

df.head()
# Out:
#    S.No       Date      Time  Age  Gender         Country       state  \
# 0     1  8/27/2014  11:29:00   37  Female   United States    Illinois
# 1     2  8/27/2014  11:29:00   44    Male   United States     Indiana
# 2     3  8/27/2014  11:29:00   32    Male          Canada  Don't Know
# 3     4  8/27/2014  11:29:00   31    Male  United Kingdom  Don't Know
# 4     5  8/27/2014  11:30:00   31    Male   United States       Texas
#
#   self_employed family_history treatment  ...               leave  \
# 0    Don't Know             No       Yes  ...       Somewhat easy
# 1    Don't Know             No        No  ...          Don't Know
# 2    Don't Know             No        No  ...  Somewhat difficult
# 3    Don't Know            Yes       Yes  ...  Somewhat difficult
# 4    Don't Know             No        No  ...          Don't Know
#
#   mental_health_consequence phys_health_consequence     coworkers supervisor  \
# ...

# %%
# Check data structure
df.info()

# Basic summary of values
df.describe(include='all')

# Check for missing values
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   S.No                       1048 non-null   int64
#  1   Date                       1048 non-null   object
#  2   Time                       1048 non-null   object
#  3   Age                        1048 non-null   int64
#  4   Gender                     1048 non-null   object
#  5   Country                    1048 non-null   object
#  6   state                      1048 non-null   object
#  7   self_employed              1048 non-null   object
#  8   family_history             1048 non-null   object
#  9   treatment                  1048 non-null   object
#  10  work_interfere             1048 non-null   object
#  11  no_employees               1048 non-null   object
#  12  remote_work                1048 non-null   object
# ...

# %%
# !pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Age distribution
sns.histplot(df['Age'], kde=True)
plt.title("Age Distribution")
plt.show()

# Treatment by Gender
sns.countplot(x='Gender', hue='treatment', data=df)
plt.title("Treatment by Gender")
plt.show()

# Family History vs Treatment
sns.countplot(x='family_history', hue='treatment', data=df)
plt.title("Family History vs Treatment")
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Crosstab: Seek Help vs Treatment
pd.crosstab(df['seek_help'], df['treatment'], normalize='index') * 100

# Grouped stats
df.groupby('mental_vs_physical')['treatment'].value_counts(normalize=True)
# Out:
# mental_vs_physical  treatment
# Don't know          No           0.571125
#                     Yes          0.428875
# No                  Yes          0.578571
#                     No           0.421429
# Yes                 No           0.501684
#                     Yes          0.498316
# Name: proportion, dtype: float64

# %%
# Basic info
df.info()

# Summary of all columns
df.describe(include='all')

# Count missing values
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   S.No                       1048 non-null   int64
#  1   Date                       1048 non-null   object
#  2   Time                       1048 non-null   object
#  3   Age                        1048 non-null   int64
#  4   Gender                     1048 non-null   object
#  5   Country                    1048 non-null   object
#  6   state                      1048 non-null   object
#  7   self_employed              1048 non-null   object
#  8   family_history             1048 non-null   object
#  9   treatment                  1048 non-null   object
#  10  work_interfere             1048 non-null   object
#  11  no_employees               1048 non-null   object
#  12  remote_work                1048 non-null   object
# ...

# %% [markdown]
# ## Dataset Overview
# This section summarizes the dataset structure, data types, and missing values (if any).

# %% [markdown]
# ### Insight 1:
# Employees with a family history of mental illness are more likely to need treatment.
# ## 📌 Summary of Findings
# - Most employees in their 20s–30s are represented.
# - Those with family history and poor employer support are more likely to need treatment.
# - Anonymity and ease of medical leave appear to influence help-seeking behavior.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x='anonymity', hue='seek_help', data=df)
plt.title("Anonymity vs Seeking Help")
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# ### Observation1:
# Employees with family history are more likely to require treatment.
#
# ### Observation2:
# People who feel their anonymity is protected are more willing to seek help.

# %%
## 🔚 Final Insights

- Most respondents are aged between 20–35.
- Family history of mental illness is a major indicator of treatment need.
- Anonymity and ease of leave are linked to whether people seek help.
- Many employees feel their workplace doesn’t treat mental health as seriously as physical health.

### Recommendations:
- Improve communication of mental health resources.
- Guarantee anonymity to encourage treatment.
- Normalize mental health discussions in the workplace.
